# %% [markdown]
# #IBM Applied D.S Capstone Project
# ##Week_3_1
#  In this notebook, we will be exploring the dataset https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M as a part of the assignment.

# %%
import pandas as pd
import numpy as np

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M',header=0)
df1=tables[0]
df2=df1[df1['Borough']!='Not assigned']
df2.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df3=df2.groupby(['Postal Code','Borough']).agg(','.join)
df3.head()
# Out:
#                                                   Neighbourhood
# Postal Code Borough
# M1B         Scarborough                          Malvern, Rouge
# M1C         Scarborough  Rouge Hill, Port Union, Highland Creek
# M1E         Scarborough       Guildwood, Morningside, West Hill
# M1G         Scarborough                                  Woburn
# M1H         Scarborough                               Cedarbrae

# %%
for index, row in df3.iterrows():
    if row["Neighbourhood"] == "Not assigned":
        row["Neighbourhood"] = row["Borough"]

# %%
df3.sort_values('Postal Code')
# Out:
#                                                                   Neighbourhood
# Postal Code Borough
# M1B         Scarborough                                          Malvern, Rouge
# M1C         Scarborough                  Rouge Hill, Port Union, Highland Creek
# M1E         Scarborough                       Guildwood, Morningside, West Hill
# M1G         Scarborough                                                  Woburn
# M1H         Scarborough                                               Cedarbrae
# M1J         Scarborough                                     Scarborough Village
# M1K         Scarborough             Kennedy Park, Ionview, East Birchmount Park
# M1L         Scarborough                         Golden Mile, Clairlea, Oakridge
# M1M         Scarborough         Cliffside, Cliffcrest, Scarborough Village West
# M1N         Scarborough                             Birch Cliff, Cliffside West
# ...

# %%
df3.shape
# Out:
# (103, 1)
